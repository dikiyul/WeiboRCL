# %%
import numpy as np
import pandas as pd

# %%
data_train = pd.read_csv('weibo_train_data(new)\weibo_train_data.txt', delimiter = "\t", header=None, names=["uid", "mid", "time", "forward_count", "comment_count", "like_count", "content"])
data_predict = pd.read_csv('weibo_predict_data(new)\weibo_predict_data.txt', delimiter = "\t", header=None, names=["uid", "mid", "time", "content"])

# %%
data_train.tail(10)
# Out:
#                                       uid                               mid  \
# 1225078  8ea66b5ac5845811f96f3777b1da0815  d481eeeed598980223fbefefb636e5dc
# 1225079  34aecfff0b411aebf22f5348631af089  897186111f41742df6dc1d472f224322
# 1225080  d0cf9d27cfee159a757eb5f20aff3de5  371faecd6c3279e034bf76ffdf221c2a
# 1225081  acc70af1567ad07cbd6b5a39b6215aa1  b132e7562caabd7f710ae2199143605e
# 1225082  70a52330e32b4c990b65d56490a5fa89  24418e8a9e63aba685b09fcb0dadc210
# 1225083  aec54746b7069c901464ec118697cc0c  1e8165f252124ea1c11124e13c2b1001
# 1225084  b98ca546114e9e6185c1b963b53f1ed4  99d60668e884f379184870888989d0eb
# 1225085  56e9116f64df76bc68b3b343b91e8d21  1742acd51ff3afa73ed1463d6f8108ca
# 1225086  2f1098ddf2ee3f50f6c70f43136321dc  cbf06ed44ff14df606c4492379ccba33
# 1225087  b4e9bc724cbc5a18577227eaec6534c2  e0d18d9f472b93d9d85d70e562b110a6
#
#                         time  forward_count  comment_count  like_count  \
# ...

# %%
data_predict.tail(10)
# Out:
#                                      uid                               mid  \
# 177913  5de2df6cd2dd03268c733e585fc5dfb1  1fda0e581f959fb76ec903d306ff823d
# 177914  0faddeeabf8b2cfd75afc6ad9c1ba2da  c07f6e80f2cdbbee36f558a99dfe3310
# 177915  a7129a594a812160e5a296f063c7e2f3  2ff7dce25b1044b3f41eaf9108925f6f
# 177916  bddfc8d56962952a221ae5aebf0cac81  fb0dd10ffd2ee0811876849551848a6e
# 177917  e4246c399859890202579cf159874544  7fed6489050651837de9bee9afd3a9a3
# 177918  dc0017eb990243ca9a706416487c80b4  3948b1f06d510e46e57f4082c584d21e
# 177919  7a0f44f56e8b1adf322fba123d73fd85  4235384d34bffdcc193f3792a6e8d26d
# 177920  0220afe08e008b01ad36cc916df43ace  d7b700bda22b352a30267677b2f610b4
# 177921  5ebfb48089167dfdec4ecc80a55beaa0  b1138d28601ff798db9d88284f58e043
# 177922  3f6d91acb1f1baaef19873ee2eeab95d  e5a8fbf8adaad66b80e943cec7214cd6
#
#                        time                                            content
# ...

# %%
data_train[['forward_count']].describe()
# Out:
#        forward_count
# count   1.225088e+06
# mean    3.540621e+00
# std     8.528489e+01
# min     0.000000e+00
# 25%     0.000000e+00
# 50%     0.000000e+00
# 75%     0.000000e+00
# max     4.185000e+04

# %%
data_train[['comment_count']].describe()
# Out:
#        comment_count
# count   1.225088e+06
# mean    1.257382e+00
# std     1.933314e+01
# min     0.000000e+00
# 25%     0.000000e+00
# 50%     0.000000e+00
# 75%     0.000000e+00
# max     7.467000e+03

# %%
data_train[['like_count']].describe()
# Out:
#          like_count
# count  1.225088e+06
# mean   2.217098e+00
# std    4.126350e+01
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    1.000000e+00
# max    1.187100e+04

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1225088 entries, 0 to 1225087
# Data columns (total 7 columns):
# uid              1225088 non-null object
# mid              1225088 non-null object
# time             1225088 non-null object
# forward_count    1225088 non-null int64
# comment_count    1225088 non-null int64
# like_count       1225088 non-null int64
# content          1225085 non-null object
# dtypes: int64(3), object(4)
# memory usage: 65.4+ MB

# %%
data_predict.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177923 entries, 0 to 177922
# Data columns (total 4 columns):
# uid        177923 non-null object
# mid        177923 non-null object
# time       177923 non-null object
# content    177922 non-null object
# dtypes: object(4)
# memory usage: 5.4+ MB

# %%
data_train[data_train.isnull().values==True]
# Out:
#                                       uid                               mid  \
# 802181   12f23f78b9ec67d2b277cd3e6fd14abe  aa8ffbf6227403ee39a2b4050a6265b7
# 902446   bf8a1b2dfafd9e89f12f311694686ded  d0b9db40ed3a2abf63ffd66c64966519
# 1159844  df9c739b546df132bb5056a6aea185dd  95f3460517d23f3923a491640d6eb686
#
#                         time  forward_count  comment_count  like_count content
# 802181   2015-02-15 09:08:32              0              0           1     NaN
# 902446   2015-04-03 14:03:25              0              0           0     NaN
# 1159844  2015-06-29 00:28:36              0              0           0     NaN

# %%
# data_train.dropna(inplace = True)

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1225088 entries, 0 to 1225087
# Data columns (total 7 columns):
# uid              1225088 non-null object
# mid              1225088 non-null object
# time             1225088 non-null object
# forward_count    1225088 non-null int64
# comment_count    1225088 non-null int64
# like_count       1225088 non-null int64
# content          1225085 non-null object
# dtypes: int64(3), object(4)
# memory usage: 65.4+ MB

# %%
da1 = data_train['uid'].value_counts().reset_index()
da1.columns = ['uid','uid_count_tra']
da1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37251 entries, 0 to 37250
# Data columns (total 2 columns):
# uid              37251 non-null object
# uid_count_tra    37251 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 582.1+ KB

# %%
da2 = data_predict['uid'].value_counts().reset_index()
da2.columns = ['uid','uid_count_pre']
da2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17536 entries, 0 to 17535
# Data columns (total 2 columns):
# uid              17536 non-null object
# uid_count_pre    17536 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 274.1+ KB

# %%
da3 = pd.merge(da1, da2, on = 'uid', how = 'inner')
da3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16837 entries, 0 to 16836
# Data columns (total 3 columns):
# uid              16837 non-null object
# uid_count_tra    16837 non-null int64
# uid_count_pre    16837 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 526.2+ KB

# %%
data_train.to_csv('data_train.csv',index = None)
data_predict.to_csv('data_pre.csv',index = None)
