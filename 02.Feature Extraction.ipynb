# %%
import numpy as np 
import pandas as pd

# %%
# data_train = pd.read_csv('data\data_train.csv')
data_timeindex = pd.read_csv('data\data_train.csv', index_col = 'time', parse_dates = True)
# Out:
#                                                   uid  \
# time
# 2015-02-23 17:41:29  d38e9bed5d98110dc2489d0d1cac3c2a
# 2015-02-14 12:49:58  fa13974743d3fe6ff40d21b872325e9e
# 2015-03-31 13:58:06  da534fe87e7a52777bee5c30573ed5fd
# 2015-06-11 20:39:57  e06a22b7e065e559a1f0bf7841a85c51
# 2015-03-10 18:02:38  f9828598f9664d4e347ef2048ce17734
# 2015-02-13 01:09:41  d80f3d3c5c1d658e82b837a4dd1af849
# 2015-07-15 01:16:24  f349a67d1cd7c8683c5bbc5f8486e193
# 2015-05-19 10:24:57  24b621c98f2594b698c0b1d60c9ae6db
# 2015-02-11 11:03:36  e44d81d630e4f382f657e72aa4b685da
# 2015-03-22 00:54:34  fbe6c953632e1b3dda66cf6118b6ab12
# 2015-02-11 19:29:04  f9a3ca6bc1e75d173cfc98ec4b108072
# 2015-04-28 00:14:05  3c68bbb9da57fcc752c8a493d91bdd3a
# 2015-02-14 23:42:23  104e8d55e98eb3cd834810088af039fe
# 2015-06-19 14:35:03  0d15005d6397fb5ce1d45e7c834f7370
# 2015-07-01 04:11:48  875a4a77b339d93f819e2c4de5bd0b57
# 2015-03-11 08:00:24  380a2219670f50dc87efce3380bea6e8
# ...

# %%
feature1 = data_timeindex['2015-02-01':'2015-04-30']
feature2 = data_timeindex['2015-03-01':'2015-05-31']
feature3 = data_timeindex['2015-04-01':'2015-06-30']
label1 = data_timeindex['2015-05-01':'2015-05-31']
label2 = data_timeindex['2015-06-01':'2015-06-30']
label3 = data_timeindex['2015-07-01':'2015-07-31']
